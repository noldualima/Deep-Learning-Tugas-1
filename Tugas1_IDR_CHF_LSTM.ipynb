# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from pandas import concat
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Load data
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/kurs_idr_chf.csv")
df
# Out:
#         Tanggal        CHF
# 0    31/01/2001   5,743.64
# 1    28/02/2001   5,856.44
# 2    31/03/2001   6,014.00
# 3    30/04/2001   6,767.74
# 4    31/05/2001   6,210.98
# ..          ...        ...
# 272  30/09/2023  16,942.00
# 273  31/10/2023  17,608.17
# 274  30/11/2023  17,528.63
# 275  31/12/2023  18,374.28
# 276  31/01/2024  18,346.00
#
# [277 rows x 2 columns]

# %%
def load_data(file):
    df = pd.read_csv(file,
    index_col=["Tanggal"],
    usecols=["Tanggal","CHF"])
    df.index = pd.to_datetime(df.index)
    return df

df
# Out:
#         Tanggal        CHF
# 0    31/01/2001   5,743.64
# 1    28/02/2001   5,856.44
# 2    31/03/2001   6,014.00
# 3    30/04/2001   6,767.74
# 4    31/05/2001   6,210.98
# ..          ...        ...
# 272  30/09/2023  16,942.00
# 273  31/10/2023  17,608.17
# 274  30/11/2023  17,528.63
# 275  31/12/2023  18,374.28
# 276  31/01/2024  18,346.00
#
# [277 rows x 2 columns]

# %%
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()

    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j + 1, i)) for j in range(n_vars)]

    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j + 1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j + 1, i)) for j in range(n_vars)]

    # put it all together
    agg = concat(cols, axis=1)
    agg.columns = names

    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)

    return agg

# %%
# Memanggil fungsi series_to_supervised dengan parameter tertentu
result = series_to_supervised(df, n_in=1, n_out=1, dropnan=True)
print(result)
# Out:
#       var1(t-1)  var2(t-1)     var1(t)    var2(t)
# 1    31/01/2001   5,743.64  28/02/2001   5,856.44
# 2    28/02/2001   5,856.44  31/03/2001   6,014.00
# 3    31/03/2001   6,014.00  30/04/2001   6,767.74
# 4    30/04/2001   6,767.74  31/05/2001   6,210.98
# 5    31/05/2001   6,210.98  30/06/2001   6,352.74
# ..          ...        ...         ...        ...
# 272  31/08/2023  17,316.00  30/09/2023  16,942.00
# 273  30/09/2023  16,942.00  31/10/2023  17,608.17
# 274  31/10/2023  17,608.17  30/11/2023  17,528.63
# 275  30/11/2023  17,528.63  31/12/2023  18,374.28
# 276  31/12/2023  18,374.28  31/01/2024  18,346.00
#
# [276 rows x 4 columns]

# %%
def normalize_data(data):
    scaler = MinMaxScaler(feature_range=(0, 1))
    data_scaled = scaler.fit_transform(data)
    return scaler, data_scaled

# %%
def inverse_normdata(scaler, dataX, yhat):
    dataX = dataX.reshape((dataX.shape[0], dataX.shape[2]))
    inv_y = np.concatenate((dataX, yhat), axis=1)
    inv_y = scaler.inverse_transform(inv_y)
    inv_y = inv_y[:, -1]
    return inv_y

# %%
from keras.layers import Dense, Activation, Dropout
from keras.layers import LSTM
from keras.layers import SimpleRNN
from keras.models import Sequential

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.metrics import mean_squared_error
from math import sqrt
from pandas import concat
from sklearn.preprocessing import MinMaxScaler

# %%
# LSTM
def build_model(train_X):
    model = Sequential()

    model.add(LSTM(256, input_shape=(train_X.shape[1], train_X.shape[2]), return_sequences=True))
    model.add(Dropout(0.3))

    model.add(LSTM(256, return_sequences=True))
    model.add(Dropout(0.3))

    model.add(LSTM(256))
    model.add(Dropout(0.3))

    model.add(Dense(1))
    model.add(Activation("sigmoid"))

    model.compile(loss="mse", optimizer="adam")
    return model

# %%
if __name__=='__main__':

    df = load_data("/content/drive/MyDrive/Colab Notebooks/kurs_idr_chf.csv")
    df['CHF']=pd.to_numeric(df['CHF'].str.replace(',', ''))
    # reframe data menjadi supervised
    data_reframed = series_to_supervised(df, 1, 1)
    df_data_reframed = pd.DataFrame(data_reframed)

    # scale data menjadi range 0-1
    scaler, data_scaled = normalize_data(data_reframed.values)
    df_data_scaled = pd.DataFrame(data_scaled, index=df_data_reframed.index, columns=df_data_reframed.columns)

    # splitting data
    # porsi_training = 80% trainin, 20% testing
    n_split = len(df_data_scaled) * 0.9565217391304348
    n = int(n_split)

    train = df_data_scaled.iloc[:n, :]
    test = df_data_scaled.iloc[n:, :]

    train_X, train_y = train.iloc[:, :-1], train.iloc[:, -1]
    test_X, test_y = test.iloc[:, :-1], test.iloc[:, -1]
    train_X = train_X.values.reshape((train_X.shape[0], 1, train_X.shape[1]))
    test_X = test_X.values.reshape((test_X.shape[0], 1, test_X.shape[1]))

    print(train_X.shape)


    train_y = pd.DataFrame(train_y)
    test_y = pd.DataFrame(test_y)

    print("train_X shape = %s, train_y shape = %s, test_X shape = %s, test_y shape = %s" % (train_X.shape, train_y.shape, test_X.shape, test_y.shape))

    model = build_model(train_X)

    history = model.fit(train_X, train_y, epochs=100, batch_size=len(train_X), validation_data=(test_X, test_y),
                        verbose=2, shuffle=False)
    model.save("rnn_model.h5")

    # plot history
    plt.plot(history.history['loss'], label='train')
    plt.legend()
    plt.show()

    # plot model and train data
    y_train = model.predict(train_X)
    inv_ymodel = inverse_normdata(scaler, train_X, y_train)
    df_inv_ymodel = pd.DataFrame(inv_ymodel, index=train_y.index)

    # plot test data
    y_test = model.predict(test_X)
    inv_y_test = inverse_normdata(scaler, test_X, y_test)

    df_inv_ytest = pd.DataFrame(inv_y_test, index=test_y.index)
    plt.plot(df, color='orange', label='Actual')
    plt.plot(df_inv_ymodel, color='green', label='Trained')
    plt.plot(df_inv_ytest, color='red', label='Predicted')
    plt.legend()
    plt.show()

    # inverse data dari 0-1 menjadi range awal
    inv_test_y = inverse_normdata(scaler, test_X, test_y)
    rmse_normal = sqrt(mean_squared_error(inv_test_y, inv_y_test))
    print('Test RMSE normal : %.3f' % rmse_normal)
    print('Test MSE normal : %.3f' % mean_squared_error(inv_test_y, inv_y_test))
# Out:
# (264, 1, 1)
# train_X shape = (264, 1, 1), train_y shape = (264, 1), test_X shape = (12, 1, 1), test_y shape = (12, 1)
# <ipython-input-536-e9ba52fb2127>:5: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df.index = pd.to_datetime(df.index)
# Epoch 1/100
# 1/1 - 7s - loss: 0.0743 - val_loss: 0.1691 - 7s/epoch - 7s/step
# Epoch 2/100
# 1/1 - 0s - loss: 0.0740 - val_loss: 0.1703 - 179ms/epoch - 179ms/step
# Epoch 3/100
# 1/1 - 0s - loss: 0.0737 - val_loss: 0.1715 - 168ms/epoch - 168ms/step
# Epoch 4/100
# 1/1 - 0s - loss: 0.0734 - val_loss: 0.1727 - 160ms/epoch - 160ms/step
# Epoch 5/100
# 1/1 - 0s - loss: 0.0731 - val_loss: 0.1739 - 153ms/epoch - 153ms/step
# Epoch 6/100
# 1/1 - 0s - loss: 0.0728 - val_loss: 0.1752 - 164ms/epoch - 164ms/step
# Epoch 7/100
# 1/1 - 0s - loss: 0.0724 - val_loss: 0.1765 - 166ms/epoch - 166ms/step
# Epoch 8/100
# 1/1 - 0s - loss: 0.0720 - val_loss: 0.1778 - 177ms/epoch - 177ms/step
# Epoch 9/100
# 1/1 - 0s - loss: 0.0717 - val_loss: 0.1792 - 147ms/epoch - 147ms/step
# Epoch 10/100
# 1/1 - 0s - loss: 0.0713 - val_loss: 0.1805 - 164ms/epoch - 164ms/step
# Epoch 11/100
# 1/1 - 0s - loss: 0.0708 - val_loss: 0.1819 - 155ms/epoch - 155ms/step
# Epoch 12/100
# 1/1 - 0s - loss: 0.0703 - val_loss: 0.1832 - 145ms/epoch - 145ms/step
# Epoch 13/100
# 1/1 - 0s - loss: 0.0697 - val_loss: 0.1845 - 141ms/epoch - 141ms/step
# Epoch 14/100
# 1/1 - 0s - loss: 0.0691 - val_loss: 0.1858 - 146ms/epoch - 146ms/step
# Epoch 15/100
# 1/1 - 0s - loss: 0.0684 - val_loss: 0.1870 - 156ms/epoch - 156ms/step
# Epoch 16/100
# 1/1 - 0s - loss: 0.0677 - val_loss: 0.1881 - 156ms/epoch - 156ms/step
# Epoch 17/100
# 1/1 - 0s - loss: 0.0667 - val_loss: 0.1891 - 166ms/epoch - 166ms/step
# Epoch 18/100
# 1/1 - 0s - loss: 0.0658 - val_loss: 0.1899 - 163ms/epoch - 163ms/step
# Epoch 19/100
# 1/1 - 0s - loss: 0.0647 - val_loss: 0.1906 - 155ms/epoch - 155ms/step
# Epoch 20/100
# 1/1 - 0s - loss: 0.0636 - val_loss: 0.1911 - 159ms/epoch - 159ms/step
# Epoch 21/100
# 1/1 - 0s - loss: 0.0621 - val_loss: 0.1914 - 173ms/epoch - 173ms/step
# Epoch 22/100
# 1/1 - 0s - loss: 0.0608 - val_loss: 0.1913 - 169ms/epoch - 169ms/step
# Epoch 23/100
# 1/1 - 0s - loss: 0.0590 - val_loss: 0.1909 - 95ms/epoch - 95ms/step
# Epoch 24/100
# 1/1 - 0s - loss: 0.0574 - val_loss: 0.1900 - 92ms/epoch - 92ms/step
# Epoch 25/100
# 1/1 - 0s - loss: 0.0555 - val_loss: 0.1884 - 96ms/epoch - 96ms/step
# Epoch 26/100
# 1/1 - 0s - loss: 0.0539 - val_loss: 0.1858 - 103ms/epoch - 103ms/step
# Epoch 27/100
# 1/1 - 0s - loss: 0.0516 - val_loss: 0.1818 - 92ms/epoch - 92ms/step
# Epoch 28/100
# 1/1 - 0s - loss: 0.0493 - val_loss: 0.1756 - 92ms/epoch - 92ms/step
# Epoch 29/100
# 1/1 - 0s - loss: 0.0469 - val_loss: 0.1669 - 98ms/epoch - 98ms/step
# Epoch 30/100
# 1/1 - 0s - loss: 0.0442 - val_loss: 0.1556 - 92ms/epoch - 92ms/step
# Epoch 31/100
# 1/1 - 0s - loss: 0.0410 - val_loss: 0.1415 - 105ms/epoch - 105ms/step
# Epoch 32/100
# 1/1 - 0s - loss: 0.0375 - val_loss: 0.1252 - 98ms/epoch - 98ms/step
# Epoch 33/100
# 1/1 - 0s - loss: 0.0338 - val_loss: 0.1072 - 97ms/epoch - 97ms/step
# Epoch 34/100
# 1/1 - 0s - loss: 0.0300 - val_loss: 0.0886 - 97ms/epoch - 97ms/step
# Epoch 35/100
# 1/1 - 0s - loss: 0.0262 - val_loss: 0.0707 - 100ms/epoch - 100ms/step
# Epoch 36/100
# 1/1 - 0s - loss: 0.0226 - val_loss: 0.0550 - 94ms/epoch - 94ms/step
# Epoch 37/100
# 1/1 - 0s - loss: 0.0196 - val_loss: 0.0421 - 98ms/epoch - 98ms/step
# Epoch 38/100
# 1/1 - 0s - loss: 0.0164 - val_loss: 0.0320 - 96ms/epoch - 96ms/step
# Epoch 39/100
# 1/1 - 0s - loss: 0.0133 - val_loss: 0.0241 - 92ms/epoch - 92ms/step
# Epoch 40/100
# 1/1 - 0s - loss: 0.0102 - val_loss: 0.0182 - 93ms/epoch - 93ms/step
# Epoch 41/100
# 1/1 - 0s - loss: 0.0080 - val_loss: 0.0138 - 118ms/epoch - 118ms/step
# Epoch 42/100
# 1/1 - 0s - loss: 0.0057 - val_loss: 0.0105 - 92ms/epoch - 92ms/step
# Epoch 43/100
# 1/1 - 0s - loss: 0.0037 - val_loss: 0.0081 - 90ms/epoch - 90ms/step
# Epoch 44/100
# 1/1 - 0s - loss: 0.0026 - val_loss: 0.0063 - 101ms/epoch - 101ms/step
# Epoch 45/100
# 1/1 - 0s - loss: 0.0016 - val_loss: 0.0049 - 92ms/epoch - 92ms/step
# Epoch 46/100
# 1/1 - 0s - loss: 0.0017 - val_loss: 0.0038 - 93ms/epoch - 93ms/step
# Epoch 47/100
# 1/1 - 0s - loss: 0.0019 - val_loss: 0.0029 - 101ms/epoch - 101ms/step
# Epoch 48/100
# 1/1 - 0s - loss: 0.0025 - val_loss: 0.0022 - 90ms/epoch - 90ms/step
# Epoch 49/100
# 1/1 - 0s - loss: 0.0028 - val_loss: 0.0017 - 93ms/epoch - 93ms/step
# Epoch 50/100
# 1/1 - 0s - loss: 0.0034 - val_loss: 0.0015 - 95ms/epoch - 95ms/step
# Epoch 51/100
# 1/1 - 0s - loss: 0.0040 - val_loss: 0.0014 - 96ms/epoch - 96ms/step
# Epoch 52/100
# 1/1 - 0s - loss: 0.0041 - val_loss: 0.0014 - 108ms/epoch - 108ms/step
# Epoch 53/100
# 1/1 - 0s - loss: 0.0042 - val_loss: 0.0014 - 94ms/epoch - 94ms/step
# Epoch 54/100
# 1/1 - 0s - loss: 0.0046 - val_loss: 0.0014 - 92ms/epoch - 92ms/step
# Epoch 55/100
# 1/1 - 0s - loss: 0.0047 - val_loss: 0.0014 - 93ms/epoch - 93ms/step
# Epoch 56/100
# 1/1 - 0s - loss: 0.0046 - val_loss: 0.0014 - 97ms/epoch - 97ms/step
# Epoch 57/100
# 1/1 - 0s - loss: 0.0042 - val_loss: 0.0014 - 93ms/epoch - 93ms/step
# Epoch 58/100
# 1/1 - 0s - loss: 0.0038 - val_loss: 0.0015 - 92ms/epoch - 92ms/step
# Epoch 59/100
# 1/1 - 0s - loss: 0.0038 - val_loss: 0.0016 - 96ms/epoch - 96ms/step
# Epoch 60/100
# 1/1 - 0s - loss: 0.0033 - val_loss: 0.0019 - 91ms/epoch - 91ms/step
# Epoch 61/100
# 1/1 - 0s - loss: 0.0032 - val_loss: 0.0022 - 119ms/epoch - 119ms/step
# Epoch 62/100
# 1/1 - 0s - loss: 0.0026 - val_loss: 0.0026 - 105ms/epoch - 105ms/step
# Epoch 63/100
# 1/1 - 0s - loss: 0.0024 - val_loss: 0.0031 - 92ms/epoch - 92ms/step
# Epoch 64/100
# 1/1 - 0s - loss: 0.0020 - val_loss: 0.0035 - 95ms/epoch - 95ms/step
# Epoch 65/100
# 1/1 - 0s - loss: 0.0019 - val_loss: 0.0039 - 97ms/epoch - 97ms/step
# Epoch 66/100
# 1/1 - 0s - loss: 0.0015 - val_loss: 0.0043 - 93ms/epoch - 93ms/step
# Epoch 67/100
# 1/1 - 0s - loss: 0.0017 - val_loss: 0.0047 - 93ms/epoch - 93ms/step
# Epoch 68/100
# 1/1 - 0s - loss: 0.0017 - val_loss: 0.0051 - 97ms/epoch - 97ms/step
# Epoch 69/100
# 1/1 - 0s - loss: 0.0015 - val_loss: 0.0056 - 91ms/epoch - 91ms/step
# Epoch 70/100
# 1/1 - 0s - loss: 0.0019 - val_loss: 0.0061 - 92ms/epoch - 92ms/step
# Epoch 71/100
# 1/1 - 0s - loss: 0.0018 - val_loss: 0.0067 - 96ms/epoch - 96ms/step
# Epoch 72/100
# 1/1 - 0s - loss: 0.0018 - val_loss: 0.0074 - 94ms/epoch - 94ms/step
# Epoch 73/100
# 1/1 - 0s - loss: 0.0018 - val_loss: 0.0079 - 104ms/epoch - 104ms/step
# Epoch 74/100
# 1/1 - 0s - loss: 0.0019 - val_loss: 0.0085 - 96ms/epoch - 96ms/step
# Epoch 75/100
# 1/1 - 0s - loss: 0.0021 - val_loss: 0.0089 - 108ms/epoch - 108ms/step
# Epoch 76/100
# 1/1 - 0s - loss: 0.0021 - val_loss: 0.0091 - 92ms/epoch - 92ms/step
# Epoch 77/100
# 1/1 - 0s - loss: 0.0020 - val_loss: 0.0090 - 95ms/epoch - 95ms/step
# Epoch 78/100
# 1/1 - 0s - loss: 0.0019 - val_loss: 0.0088 - 93ms/epoch - 93ms/step
# Epoch 79/100
# 1/1 - 0s - loss: 0.0018 - val_loss: 0.0084 - 96ms/epoch - 96ms/step
# Epoch 80/100
# 1/1 - 0s - loss: 0.0020 - val_loss: 0.0079 - 90ms/epoch - 90ms/step
# Epoch 81/100
# 1/1 - 0s - loss: 0.0017 - val_loss: 0.0074 - 96ms/epoch - 96ms/step
# Epoch 82/100
# 1/1 - 0s - loss: 0.0017 - val_loss: 0.0071 - 91ms/epoch - 91ms/step
# Epoch 83/100
# 1/1 - 0s - loss: 0.0017 - val_loss: 0.0068 - 106ms/epoch - 106ms/step
# Epoch 84/100
# 1/1 - 0s - loss: 0.0016 - val_loss: 0.0066 - 91ms/epoch - 91ms/step
# Epoch 85/100
# 1/1 - 0s - loss: 0.0016 - val_loss: 0.0064 - 91ms/epoch - 91ms/step
# Epoch 86/100
# 1/1 - 0s - loss: 0.0016 - val_loss: 0.0063 - 90ms/epoch - 90ms/step
# Epoch 87/100
# 1/1 - 0s - loss: 0.0016 - val_loss: 0.0061 - 96ms/epoch - 96ms/step
# Epoch 88/100
# 1/1 - 0s - loss: 0.0015 - val_loss: 0.0059 - 90ms/epoch - 90ms/step
# Epoch 89/100
# 1/1 - 0s - loss: 0.0016 - val_loss: 0.0058 - 94ms/epoch - 94ms/step
# Epoch 90/100
# 1/1 - 0s - loss: 0.0017 - val_loss: 0.0056 - 93ms/epoch - 93ms/step
# Epoch 91/100
# 1/1 - 0s - loss: 0.0017 - val_loss: 0.0054 - 91ms/epoch - 91ms/step
# Epoch 92/100
# 1/1 - 0s - loss: 0.0015 - val_loss: 0.0053 - 93ms/epoch - 93ms/step
# Epoch 93/100
# 1/1 - 0s - loss: 0.0016 - val_loss: 0.0052 - 109ms/epoch - 109ms/step
# Epoch 94/100
# 1/1 - 0s - loss: 0.0016 - val_loss: 0.0051 - 89ms/epoch - 89ms/step
# Epoch 95/100
# 1/1 - 0s - loss: 0.0015 - val_loss: 0.0051 - 100ms/epoch - 100ms/step
# Epoch 96/100
# 1/1 - 0s - loss: 0.0015 - val_loss: 0.0051 - 93ms/epoch - 93ms/step
# Epoch 97/100
# 1/1 - 0s - loss: 0.0016 - val_loss: 0.0051 - 90ms/epoch - 90ms/step
# Epoch 98/100
# 1/1 - 0s - loss: 0.0015 - val_loss: 0.0052 - 97ms/epoch - 97ms/step
# Epoch 99/100
# 1/1 - 0s - loss: 0.0016 - val_loss: 0.0054 - 96ms/epoch - 96ms/step
# Epoch 100/100
# 1/1 - 0s - loss: 0.0014 - val_loss: 0.0055 - 97ms/epoch - 97ms/step
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 9/9 [==============================] - 1s 7ms/step
# 1/1 [==============================] - 0s 25ms/step
# Test RMSE normal : 967.072
# Test MSE normal : 935227.917
